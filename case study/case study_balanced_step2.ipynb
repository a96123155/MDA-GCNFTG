# %%
import numpy as np
import pandas as pd

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import classification_report
from collections import Counter
import re
from tqdm import trange

# %%
database_data = pd.read_csv('database_file汇总.csv').drop_duplicates()
database_data
# Out:
#                miRNA miRBase Update ID              disease   Cancer Subtype
# 0       hsa-miR-106a   hsa-miR-106a-5p             lymphoma  B cell lymphoma
# 1         hsa-let-7g     hsa-let-7g-5p             lymphoma  B cell lymphoma
# 2      hsa-miR-17-5p     hsa-miR-17-5p             lymphoma  B cell lymphoma
# 3         hsa-let-7f     hsa-let-7f-5p             lymphoma  B cell lymphoma
# 4         hsa-let-7a     hsa-let-7a-5p             lymphoma  B cell lymphoma
# ...              ...               ...                  ...              ...
# 98742    hsa-mir-34a               NaN        Glioblastoma               NaN
# 98747    hsa-mir-15b               NaN   Stomach Neoplasms               NaN
# 98748   hsa-mir-16-1               NaN   Stomach Neoplasms               NaN
# 98749   hsa-mir-16-2               NaN   Stomach Neoplasms               NaN
# 98755   hsa-mir-449a               NaN  Prostatic Neoplasms              NaN
#
# [59765 rows x 4 columns]

# %%
def new_MDA(results_df, task, balanced = True):
    new_MDA = results_df[results_df['y_true'] == 0][results_df['y_pred'] == 1]
    if balanced:
        new_MDA.to_csv(task + '_balanced_new_MDA.csv')
    else:
        new_MDA.to_csv(task + '_unbalanced_new_MDA.csv')
        
    new_MDA_simplied = new_MDA[['miRNA_y', 'disease_y', 'y_prob']]

    temp = []
    for item in new_MDA_simplied['disease_y'].tolist():
        item = item.replace("['",'').replace("']", "")
        temp.append(item)
    new_MDA_simplied['disease_newMDA'] = temp
    
    return new_MDA, new_MDA_simplied

# %%
def database_data_miRNA_in_newMDA_results(database_data, new_MDA_simplied):
    database_data_miRNA_in_results = database_data[database_data['miRNA'].isin(new_MDA_simplied['miRNA_y'])]
    database_data_miRNA_in_results_2 = database_data[database_data['miRBase Update ID'].isin(new_MDA_simplied['miRNA_y'])]
    if database_data_miRNA_in_results_2.shape[0] != 0:
        print('miRBase Update ID shoud be used!!!!!!')
        database_data_miRNA_in_results = pd.concat([database_data_miRNA_in_results, ], axis = 0)
    return database_data_miRNA_in_results

# %%
def newMDA_in_database(new_MDA_simplied, database_data_miRNA_in_results):
    
    for i in trange(new_MDA_simplied.shape[0]):
        print('-------------------------{}-th new MDA--------------------------------------------'.format(i))
        miRNA = new_MDA_simplied.iloc[i]['miRNA_y']
        disease_of_miRNA = new_MDA_simplied.iloc[i]['disease_newMDA']
        print('miRNA = {}  ||  disease_of_miRNA = {}'.format(miRNA, disease_of_miRNA))
        disease_of_miRNA = disease_of_miRNA.split(' ')
        database_data_of_miRNA = database_data_miRNA_in_results[database_data_miRNA_in_results['miRNA'] == miRNA]

        for str_ in disease_of_miRNA:
            res = database_data_of_miRNA.loc[database_data_of_miRNA['disease'].str.contains(str_)]
            print(str_, '--> ', res.values, '\n')

# %%
def run(task, database_data):
    results = pd.read_csv(task + '_balanced_case_study_0.csv', index_col = 0)
    new_MDA_origin, new_MDA_simplied = new_MDA(results, task, True)
    database_data_miRNA_in_results = database_data_miRNA_in_newMDA_results(database_data, new_MDA_simplied)
    newMDA_in_database(new_MDA_simplied, database_data_miRNA_in_results)
    return results, new_MDA, new_MDA_simplied, database_data_miRNA_in_results

# %%
results_Tp, new_MDA_Tp, new_MDA_simplied_Tp, database_data_miRNA_in_results_Tp = run(task = 'Tp', database_data = database_data)
# Out:
# /home/chujunyi/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/chujunyi/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#  13%|█▎        | 10/77 [00:00<00:01, 66.69it/s]
# -------------------------0-th new MDA--------------------------------------------
# miRNA = hsa-mir-324  ||  disease_of_miRNA = Vascular Calcification
# Vascular -->  []
#
# Calcification -->  []
#
# -------------------------1-th new MDA--------------------------------------------
# miRNA = hsa-mir-371a  ||  disease_of_miRNA = Vascular Calcification
# Vascular -->  []
#
# Calcification -->  []
#
# -------------------------2-th new MDA--------------------------------------------
# miRNA = hsa-mir-548c  ||  disease_of_miRNA = Uterine Cervical Neoplasms
# Uterine -->  []
#
# Cervical -->  []
#
# Neoplasms -->  [['hsa-mir-548c' nan 'Breast Neoplasms' nan]
#  ['hsa-mir-548c' nan 'Ovarian Neoplasms' nan]
#  ['hsa-mir-548c' nan 'Rectal Neoplasms' nan]]
#
# -------------------------3-th new MDA--------------------------------------------
# miRNA = hsa-mir-640  ||  disease_of_miRNA = Skin Neoplasms
# Skin -->  []
#
# Neoplasms -->  [['hsa-mir-640' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-640' nan 'Stomach Neoplasms' nan]]
#
# -------------------------4-th new MDA--------------------------------------------
# miRNA = hsa-mir-10b  ||  disease_of_miRNA = Sepsis
# Sepsis -->  []
#
# -------------------------5-th new MDA--------------------------------------------
# miRNA = hsa-mir-300  ||  disease_of_miRNA = Sepsis
# Sepsis -->  []
#
# -------------------------6-th new MDA--------------------------------------------
# miRNA = hsa-mir-15a  ||  disease_of_miRNA = Salivary Gland Neoplasms
# Salivary -->  [['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]]
#
# Gland -->  [['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]]
#
# Neoplasms -->  [['hsa-mir-15a' nan 'Pituitary Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Prostate Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Kidney Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Breast Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Neoplasms [unspecific]' nan]
#  ['hsa-mir-15a' nan 'Hematologic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Colon Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Laryngeal Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Head And Neck Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Myeloproliferative Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Pancreatic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Bladder Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Esophageal Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Prostatic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Head and Neck Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Colonic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Urinary Bladder Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Neoplasms' nan]]
#
# -------------------------7-th new MDA--------------------------------------------
# miRNA = hsa-mir-589  ||  disease_of_miRNA = Salivary Gland Neoplasms
# Salivary -->  []
#
# Gland -->  []
#
# Neoplasms -->  [['hsa-mir-589' nan 'Gastric Neoplasms' nan]]
#
# -------------------------8-th new MDA--------------------------------------------
# miRNA = hsa-mir-378c  ||  disease_of_miRNA = Renal Insufficiency
# Renal -->  [['hsa-mir-378c' nan 'Carcinoma, Renal Cell' nan]]
#
# Insufficiency -->  []
#
# -------------------------9-th new MDA--------------------------------------------
# miRNA = hsa-mir-296  ||  disease_of_miRNA = Renal Insufficiency
# Renal -->  []
#
# Insufficiency -->  []
#
# -------------------------10-th new MDA--------------------------------------------
# miRNA = hsa-mir-2355  ||  disease_of_miRNA = Psoriasis
# Psoriasis -->  []
#
# -------------------------11-th new MDA--------------------------------------------
# miRNA = hsa-mir-641  ||  disease_of_miRNA = Papilary thyroid carcinoma
# Papilary -->  []
#  31%|███       | 24/77 [00:00<00:00, 56.74it/s]
# thyroid -->  []
#
# carcinoma -->  []
#
# -------------------------12-th new MDA--------------------------------------------
# miRNA = hsa-mir-320d  ||  disease_of_miRNA = Pancreatic Neoplasms
# Pancreatic -->  []
#
# Neoplasms -->  [['hsa-mir-320d' nan 'Breast Neoplasms' nan]]
#
# -------------------------13-th new MDA--------------------------------------------
# miRNA = hsa-mir-503  ||  disease_of_miRNA = Ovary Syndrome
# Ovary -->  []
#
# Syndrome -->  [['hsa-mir-503' nan 'Nephrotic Syndrome' nan]]
#
# -------------------------14-th new MDA--------------------------------------------
# miRNA = hsa-mir-561  ||  disease_of_miRNA = Osteoporosis
# Osteoporosis -->  []
#
# -------------------------15-th new MDA--------------------------------------------
# miRNA = hsa-mir-647  ||  disease_of_miRNA = Osteoarthritis
# Osteoarthritis -->  []
#
# -------------------------16-th new MDA--------------------------------------------
# miRNA = hsa-mir-1181  ||  disease_of_miRNA = Oligodendroglioma
# Oligodendroglioma -->  []
#
# -------------------------17-th new MDA--------------------------------------------
# miRNA = hsa-mir-922  ||  disease_of_miRNA = Nevus, Pigmented
# Nevus, -->  []
#
# Pigmented -->  []
#
# -------------------------18-th new MDA--------------------------------------------
# miRNA = hsa-mir-664  ||  disease_of_miRNA = Neurodegenerative Diseases
# Neurodegenerative -->  []
#
# Diseases -->  []
#
# -------------------------19-th new MDA--------------------------------------------
# miRNA = hsa-mir-191  ||  disease_of_miRNA = Nephrosclerosis
# Nephrosclerosis -->  []
#
# -------------------------20-th new MDA--------------------------------------------
# miRNA = hsa-mir-431  ||  disease_of_miRNA = Myocytes, Cardiac
# Myocytes, -->  []
#
# Cardiac -->  []
#
# -------------------------21-th new MDA--------------------------------------------
# miRNA = hsa-mir-136  ||  disease_of_miRNA = Myocardium
# Myocardium -->  []
#
# -------------------------22-th new MDA--------------------------------------------
# miRNA = hsa-mir-637  ||  disease_of_miRNA = Multiple Sclerosis
# Multiple -->  []
#
# Sclerosis -->  []
#
# -------------------------23-th new MDA--------------------------------------------
# miRNA = hsa-mir-449b  ||  disease_of_miRNA = Mouth Neoplasms
# Mouth -->  []
#
# Neoplasms -->  [['hsa-mir-449b' nan 'Prostate Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Neoplasms [unspecific]' nan]
#  ['hsa-mir-449b' nan 'Liver Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Salivary Gland Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Ovarian Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Bladder Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Stomach Neoplasms' nan]]
#
# -------------------------24-th new MDA--------------------------------------------
# miRNA = hsa-mir-769  ||  disease_of_miRNA = Mastocytosis, Systemic
# Mastocytosis, -->  []
#
# Systemic -->  []
#
# -------------------------25-th new MDA--------------------------------------------
# miRNA = hsa-mir-654  ||  disease_of_miRNA = Lymphoma, Large-Cell, Anaplastic
# Lymphoma, -->  []
#
# Large-Cell, -->  []
#
# Anaplastic -->  []
#
# -------------------------26-th new MDA--------------------------------------------
# miRNA = hsa-mir-513c  ||  disease_of_miRNA = Lymphoma, Extranodal NK-T-Cell
# Lymphoma, -->  []
#
# Extranodal -->  []
#
# NK-T-Cell -->  []
#
# -------------------------27-th new MDA--------------------------------------------
# miRNA = hsa-mir-601  ||  disease_of_miRNA = Lupus Erythematosus, Systemic
# Lupus -->  [['hsa-mir-601' nan 'Lupus Vulgaris' nan]]
#
# Erythematosus, -->  []
#
# Systemic -->  []
#
# -------------------------28-th new MDA--------------------------------------------
#  39%|███▉      | 30/77 [00:00<00:00, 57.54it/s]
# miRNA = hsa-mir-1827  ||  disease_of_miRNA = Lupus Erythematosus, Systemic
# Lupus -->  []
#
# Erythematosus, -->  []
#
# Systemic -->  []
#
# -------------------------29-th new MDA--------------------------------------------
# miRNA = hsa-mir-582  ||  disease_of_miRNA = Lung Neoplasms
# Lung -->  [['hsa-mir-582' nan 'Lung Neoplasms' nan]]
#
# Neoplasms -->  [['hsa-mir-582' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-582' nan 'Prostate Neoplasms' nan]]
#
# -------------------------30-th new MDA--------------------------------------------
# miRNA = hsa-mir-151a  ||  disease_of_miRNA = Lung Diseases
# Lung -->  [['hsa-mir-151a' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-151a' nan 'Adenocarcinoma, Lung' nan]
#  ['hsa-mir-151a' nan 'Carcinoma, Non-Small-Cell Lung' nan]]
#
# Diseases -->  [['hsa-mir-151a' nan 'Cardiovascular Diseases [unspecific]' nan]]
#
# -------------------------31-th new MDA--------------------------------------------
# miRNA = hsa-mir-212  ||  disease_of_miRNA = Long QT Syndrome
# Long -->  []
#
# QT -->  []
#
# Syndrome -->  [['hsa-mir-212' nan 'Lofgren Syndrome' nan]]
#
# -------------------------32-th new MDA--------------------------------------------
# miRNA = hsa-mir-661  ||  disease_of_miRNA = Leukemia, Promyelocytic, Acute
# Leukemia, -->  []
#
# Promyelocytic, -->  []
#
# Acute -->  []
#
# -------------------------33-th new MDA--------------------------------------------
# miRNA = hsa-mir-374a  ||  disease_of_miRNA = Leukemia, Myeloid, Chronic-Phase
# Leukemia, -->  []
#
# Myeloid, -->
#  57%|█████▋    | 44/77 [00:00<00:00, 48.98it/s]
#  []
#
# Chronic-Phase -->  []
#
# -------------------------34-th new MDA--------------------------------------------
# miRNA = hsa-mir-522  ||  disease_of_miRNA = Leukemia, Myelogenous, Chronic, BCR-ABL Positive
# Leukemia, -->  []
#
# Myelogenous, -->  []
#
# Chronic, -->  []
#
# BCR-ABL -->  []
#
# Positive -->  []
#
# -------------------------35-th new MDA--------------------------------------------
# miRNA = hsa-mir-2861  ||  disease_of_miRNA = Leukemia, B-Cell
# Leukemia, -->  []
#
# B-Cell -->  []
#
# -------------------------36-th new MDA--------------------------------------------
# miRNA = hsa-mir-641  ||  disease_of_miRNA = Leiomyosarcoma
# Leiomyosarcoma -->  []
#
# -------------------------37-th new MDA--------------------------------------------
# miRNA = hsa-mir-571  ||  disease_of_miRNA = Laryngeal Neoplasms
# Laryngeal -->  []
#
# Neoplasms -->  []
#
# -------------------------38-th new MDA--------------------------------------------
# miRNA = hsa-mir-655  ||  disease_of_miRNA = Kidney Neoplasms
# Kidney -->  []
#
# Neoplasms -->  [['hsa-mir-655' nan 'Pituitary Neoplasms' nan]]
#
# -------------------------39-th new MDA--------------------------------------------
# miRNA = hsa-mir-516a  ||  disease_of_miRNA = Ischemic Preconditioning
# Ischemic -->  []
#
# Preconditioning -->  []
#
# -------------------------40-th new MDA--------------------------------------------
# miRNA = hsa-mir-942  ||  disease_of_miRNA = Ischemia
# Ischemia -->  []
#
# -------------------------41-th new MDA--------------------------------------------
# miRNA = hsa-mir-181  ||  disease_of_miRNA = Inflammation
# Inflammation -->  [['hsa-mir-181' nan 'Wound Inflammation' nan]
#  ['hsa-mir-181' nan 'Inflammation' nan]]
#
# -------------------------42-th new MDA--------------------------------------------
# miRNA = hsa-mir-212  ||  disease_of_miRNA = HIV
# HIV -->  []
#
# -------------------------43-th new MDA--------------------------------------------
# miRNA = hsa-mir-7  ||  disease_of_miRNA = Hepatitis C, Chronic
# Hepatitis -->  []
#
# C, -->  []
#
# Chronic -->  [['hsa-mir-7' nan 'Leukemia, Myeloid, Chronic' nan]]
#
# -------------------------44-th new MDA--------------------------------------------
# miRNA = hsa-mir-1245a  ||  disease_of_miRNA = Hepatitis
# Hepatitis -->  []
#
# -------------------------45-th new MDA--------------------------------------------
# miRNA = hsa-mir-448  ||  disease_of_miRNA = Helplessness, Learned
# Helplessness, -->  []
#
# Learned -->  []
#
# -------------------------46-th new MDA--------------------------------------------
# miRNA = hsa-mir-545  ||  disease_of_miRNA = HBV Infection
# HBV
#  79%|███████▉  | 61/77 [00:01<00:00, 52.93it/s]
# -->  []
#
# Infection -->  []
#
# -------------------------47-th new MDA--------------------------------------------
# miRNA = hsa-mir-622  ||  disease_of_miRNA = Graves Disease
# Graves -->  []
#
# Disease -->  []
#
# -------------------------48-th new MDA--------------------------------------------
# miRNA = hsa-mir-758  ||  disease_of_miRNA = Graft vs Host Disease
# Graft -->  []
#
# vs -->  []
#
# Host -->  []
#
# Disease -->  [['hsa-mir-758' nan 'Cardiovascular Diseases [unspecific]' nan]]
#
# -------------------------49-th new MDA--------------------------------------------
# miRNA = hsa-mir-320a  ||  disease_of_miRNA = Glomerulonephritis, IGA
# Glomerulonephritis, -->  []
#
# IGA -->  []
#
# -------------------------50-th new MDA--------------------------------------------
# miRNA = hsa-mir-598  ||  disease_of_miRNA = Glomerulonephritis
# Glomerulonephritis -->  []
#
# -------------------------51-th new MDA--------------------------------------------
# miRNA = hsa-mir-648  ||  disease_of_miRNA = Frontotemporal Lobar Degeneration
# Frontotemporal -->  []
#
# Lobar -->  []
#
# Degeneration -->  []
#
# -------------------------52-th new MDA--------------------------------------------
# miRNA = hsa-mir-659  ||  disease_of_miRNA = Focal Epithelial Hyperplasia
# Focal -->  []
#
# Epithelial -->  []
#
# Hyperplasia -->  []
#
# -------------------------53-th new MDA--------------------------------------------
# miRNA = hsa-mir-205  ||  disease_of_miRNA = Fatty Liver, Alcoholic
# Fatty -->  []
#
# Liver, -->  []
#
# Alcoholic -->  []
#
# -------------------------54-th new MDA--------------------------------------------
# miRNA = hsa-mir-33a  ||  disease_of_miRNA = Endometrial Neoplasms
# Endometrial -->  []
#
# Neoplasms -->  [['hsa-mir-33a' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-33a' nan 'Breast Neoplasms' nan]
#  ['hsa-mir-33a' nan 'Laryngeal Neoplasms' nan]
#  ['hsa-mir-33a' nan 'Colon Neoplasms' nan]
#  ['hsa-mir-33a' nan 'Colorectal Neoplasms' nan]]
#
# -------------------------55-th new MDA--------------------------------------------
# miRNA = hsa-mir-30c  ||  disease_of_miRNA = Encephalomyelitis, Autoimmune, Experimental
# Encephalomyelitis, -->  []
#
# Autoimmune, -->  []
#
# Experimental -->  []
#
# -------------------------56-th new MDA--------------------------------------------
# miRNA = hsa-mir-873  ||  disease_of_miRNA = Diabetic Retinopathy
# Diabetic -->  []
#
# Retinopathy -->  []
#
# -------------------------57-th new MDA--------------------------------------------
# miRNA = hsa-mir-15b  ||  disease_of_miRNA = Diabetic Nephropathies
# Diabetic -->  [['hsa-mir-15b' nan 'Diabetic Nephropathy' nan]]
#
# Nephropathies -->  []
#
# -------------------------58-th new MDA--------------------------------------------
# miRNA = hsa-mir-512  ||  disease_of_miRNA = Diabetes Mellitus, Type 1
# Diabetes -->  []
#
# Mellitus, -->  []
#
# Type -->  []
#
# 1 -->  []
#
# -------------------------59-th new MDA--------------------------------------------
# miRNA = hsa-mir-378f  ||  disease_of_miRNA = Diabetes Complications
# Diabetes -->  []
#
# Complications -->  []
#
# -------------------------60-th new MDA--------------------------------------------
# miRNA = hsa-mir-198  ||  disease_of_miRNA = Cystic Fibrosis
# Cystic -->  []
#
# Fibrosis -->  []
#
# -------------------------61-th new MDA--------------------------------------------
# miRNA = hsa-mir-494  ||  disease_of_miRNA = Colitis, Ulcerative
# Colitis, -->  []
#
# Ulcerative -->  []
#
# -------------------------62-th new MDA--------------------------------------------
# miRNA = hsa-mir-143  ||  disease_of_miRNA = Colitis
# Colitis -->  [['hsa-mir-143' nan 'Colitis, Ulcerative' nan]]
#
# -------------------------63-th new MDA--------------------------------------------
# miRNA = hsa-mir-100  ||  disease_of_miRNA = Cocaine-Related Disorders
# Cocaine-Related -->  []
#
# Disorders -->  [['hsa-mir-100' nan 'Muscular Disorders, Atrophic' nan]]
#
# -------------------------64-th new MDA--------------------------------------------
# miRNA = hsa-mir-424  ||  disease_of_miRNA = Chondrodysplasia Punctata
# Chondrodysplasia -->  []
#
# Punctata -->  []
#
# -------------------------65-th new MDA--------------------------------------------
# miRNA = hsa-mir-337  ||  disease_of_miRNA = Cervical Neoplasms
# Cervical -->  [['hsa-mir-337' nan 'Carcinoma, Cervical' nan]]
#
# Neoplasms -->  [['hsa-mir-337' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-337' nan 'Salivary Gland Neoplasms' nan]
#  ['hsa-mir-337' nan 'Colorectal Neoplasms' nan]]
#
# -------------------------66-th new MDA--------------------------------------------
# miRNA = hsa-mir-370  ||  disease_of_miRNA = Carcinoma, Renal Cell
#  88%|████████▊ | 68/77 [00:01<00:00, 36.01it/s]
# Carcinoma, -->  [['hsa-mir-370' nan 'Carcinoma, Gastric' nan]
#  ['hsa-mir-370' nan 'Carcinoma, Oral' nan]
#  ['hsa-mir-370' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-370' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-370' nan 'Carcinoma, Lung' nan]
#  ['hsa-mir-370' nan 'Squamous Cell Carcinoma, Esophageal' nan]
#  ['hsa-mir-370' nan
#   'Squamous Cell Carcinoma, Laryngeal or Hypopharyngeal' nan]]
#
# Renal -->  []
#
# Cell -->  [['hsa-mir-370' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-370' nan 'Squamous Cell Carcinoma, Esophageal' nan]
#  ['hsa-mir-370' nan
#   'Squamous Cell Carcinoma, Laryngeal or Hypopharyngeal' nan]]
#
# -------------------------67-th new MDA--------------------------------------------
# miRNA = hsa-mir-603  ||  disease_of_miRNA = Carcinoma, Renal Cell
# Carcinoma, -->  [['hsa-mir-603' nan 'Carcinoma, Breast, Triple Negative' nan]]
#
# Renal -->  []
#
# Cell -->  []
#
# -------------------------68-th new MDA--------------------------------------------
# miRNA = hsa-mir-30b  ||  disease_of_miRNA = Carcinoma, Ehrlich Tumor
# Carcinoma, -->  [['hsa-mir-30b' nan 'Squamous Cell Carcinoma, Lung' nan]
#  ['hsa-mir-30b' nan 'Carcinoma, Breast' nan]
#  ['hsa-mir-30b' nan 'Carcinoma, Laryngeal' nan]
#  ['hsa-mir-30b' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-30b' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-30b' nan 'Carcinoma, Renal Cell' nan]
#  ['hsa-mir-30b' nan 'Carcinoma, Cervical' nan]
#  ['hsa-mir-30b' nan 'Carcinoma, Esophageal' nan]
#  ['hsa-mir-30b' nan 'Squamous Cell Carcinoma, Oral' nan]]
#
# Ehrlich -->  []
#
# Tumor -->  []
#
# -------------------------69-th new MDA--------------------------------------------
# miRNA = hsa-mir-154  ||  disease_of_miRNA = Burns
# Burns -->  []
#
# -------------------------70-th new MDA--------------------------------------------
# miRNA = hsa-mir-527  ||  disease_of_miRNA = Arthritis
# Arthritis -->  []
#
# -------------------------71-th new MDA--------------------------------------------
# miRNA = hsa-mir-610  ||  disease_of_miRNA = Angina, Unstable
# Angina, -->  []
#
# Unstable -->  []
#
# -------------------------72-th new MDA--------------------------------------------
# miRNA = hsa-mir-410  ||  disease_of_miRNA = Alzheimer Disease
# Alzheimer -->  []
#
# Disease -->  [['hsa-mir-410' nan 'Pelvic Inflammatory Disease' nan]]
#
# -------------------------73-th new MDA--------------------------------------------
# miRNA = hsa-mir-147b  ||  disease_of_miRNA = Adenoma
# 100%|██████████| 77/77 [00:01<00:00, 50.01it/s]
# Adenoma -->  []
#
# -------------------------74-th new MDA--------------------------------------------
# miRNA = hsa-mir-451b  ||  disease_of_miRNA = Acute Lung Injury
# Acute -->  []
#
# Lung -->  [['hsa-mir-451b' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-451b' nan 'Carcinoma, Non-Small-Cell Lung' nan]]
#
# Injury -->  []
#
# -------------------------75-th new MDA--------------------------------------------
# miRNA = hsa-mir-501  ||  disease_of_miRNA = Acquired Immunodeficiency Syndrome
# Acquired -->  []
#
# Immunodeficiency -->  []
#
# Syndrome -->  []
#
# -------------------------76-th new MDA--------------------------------------------
# miRNA = hsa-mir-1273a  ||  disease_of_miRNA = Abortion, Habitual
# Abortion, -->  []
#
# Habitual -->  []

# %%
results_Tm, new_MDA_Tm, new_MDA_simplied_Tm, database_data_miRNA_in_results_Tm = run(task = 'Tm', database_data = database_data)
# Out:
# /home/chujunyi/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/chujunyi/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   4%|▍         | 2/51 [00:00<00:02, 18.52it/s]
# -------------------------0-th new MDA--------------------------------------------
# miRNA = hsa-mir-551a  ||  disease_of_miRNA = Waldenstrom Macroglobulinemia
# Waldenstrom -->  []
#
# Macroglobulinemia -->  []
#
# -------------------------1-th new MDA--------------------------------------------
# miRNA = hsa-mir-611  ||  disease_of_miRNA = Waldenstrom Macroglobulinemia
# Waldenstrom -->  []
#
# Macroglobulinemia -->  []
#
# -------------------------2-th new MDA--------------------------------------------
# miRNA = hsa-mir-324  ||  disease_of_miRNA = Vascular Calcification
# Vascular -->  []
#
# Calcification -->  []
#
# -------------------------3-th new MDA--------------------------------------------
# miRNA = hsa-mir-371a  ||  disease_of_miRNA = Vascular Calcification
# Vascular -->  []
#
# Calcification -->  []
#
# -------------------------4-th new MDA--------------------------------------------
# miRNA = hsa-mir-300  ||  disease_of_miRNA = Sepsis
# Sepsis -->  []
#
# -------------------------5-th new MDA--------------------------------------------
# miRNA = hsa-mir-10b  ||  disease_of_miRNA = Sepsis
# Sepsis -->  []
#
# -------------------------6-th new MDA--------------------------------------------
# miRNA = hsa-mir-146a  ||  disease_of_miRNA = Salivary Gland Neoplasms
# Salivary -->  []
#
# Gland -->  []
#
# Neoplasms -->
#  24%|██▎       | 12/51 [00:00<00:01, 25.51it/s]
# [['hsa-mir-146a' nan 'Pancreatic Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Prostate Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Breast Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Thyroid Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Ovarian Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Gastrointestinal Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Esophageal Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Nasopharyngeal Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Digestive System Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Neoplasms [unspecific]' nan]
#  ['hsa-mir-146a' nan 'Skin Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Endometrial Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Head And Neck Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Bladder Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Cervical Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Colon Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Liver Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Prostatic Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Uterine Cervical Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Colonic Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Stomach Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Urinary Bladder Neoplasms' nan]
#  ['hsa-mir-146a' nan 'Colorectal Neoplasms' nan]]
#
# -------------------------7-th new MDA--------------------------------------------
# miRNA = hsa-mir-15a  ||  disease_of_miRNA = Salivary Gland Neoplasms
# Salivary -->  [['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]]
#
# Gland -->  [['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]]
#
# Neoplasms -->  [['hsa-mir-15a' nan 'Pituitary Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Prostate Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Kidney Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Breast Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Neoplasms [unspecific]' nan]
#  ['hsa-mir-15a' nan 'Hematologic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Colon Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Laryngeal Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Head And Neck Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Myeloproliferative Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Pancreatic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Bladder Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Esophageal Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Prostatic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Head and Neck Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Colonic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Urinary Bladder Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Neoplasms' nan]]
#
# -------------------------8-th new MDA--------------------------------------------
# miRNA = hsa-mir-589  ||  disease_of_miRNA = Salivary Gland Neoplasms
# Salivary -->  []
#
# Gland -->  []
#
# Neoplasms -->  [['hsa-mir-589' nan 'Gastric Neoplasms' nan]]
#
# -------------------------9-th new MDA--------------------------------------------
# miRNA = hsa-mir-378c  ||  disease_of_miRNA = Renal Insufficiency
# Renal -->  [['hsa-mir-378c' nan 'Carcinoma, Renal Cell' nan]]
#
# Insufficiency -->  []
#
# -------------------------10-th new MDA--------------------------------------------
# miRNA = hsa-mir-518a  ||  disease_of_miRNA = Pulmonary Disease, Chronic Obstructive
# Pulmonary -->  []
#
# Disease, -->  []
#
# Chronic -->  []
#
# Obstructive -->  []
#
# -------------------------11-th new MDA--------------------------------------------
# miRNA = hsa-mir-641  ||  disease_of_miRNA = Papilary thyroid carcinoma
# Papilary -->  []
#
# thyroid -->  []
#
# carcinoma -->  []
#
# -------------------------12-th new MDA--------------------------------------------
# miRNA = hsa-mir-561  ||  disease_of_miRNA = Osteoporosis
# Osteoporosis -->  []
#
# -------------------------13-th new MDA--------------------------------------------
# miRNA = hsa-mir-410  ||  disease_of_miRNA = Osteoporosis
# Osteoporosis -->  []
#
# -------------------------14-th new MDA--------------------------------------------
# miRNA = hsa-mir-1280  ||  disease_of_miRNA = Osteoarthritis
# Osteoarthritis -->  []
#
# -------------------------15-th new MDA--------------------------------------------
# miRNA = hsa-mir-647  ||  disease_of_miRNA = Osteoarthritis
# Osteoarthritis
#  51%|█████     | 26/51 [00:00<00:00, 34.11it/s]
# -->  []
#
# -------------------------16-th new MDA--------------------------------------------
# miRNA = hsa-mir-18a  ||  disease_of_miRNA = Neurofibromatosis 2
# Neurofibromatosis -->  []
#
# 2 -->  [['hsa-mir-18a' nan 'Diabetes Mellitus, Type 2' nan]]
#
# -------------------------17-th new MDA--------------------------------------------
# miRNA = hsa-mir-431  ||  disease_of_miRNA = Myocytes, Cardiac
# Myocytes, -->  []
#
# Cardiac -->  []
#
# -------------------------18-th new MDA--------------------------------------------
# miRNA = hsa-mir-181d  ||  disease_of_miRNA = Musculoskeletal Abnormalities
# Musculoskeletal -->  []
#
# Abnormalities -->  []
#
# -------------------------19-th new MDA--------------------------------------------
# miRNA = hsa-mir-769  ||  disease_of_miRNA = Mastocytosis, Systemic
# Mastocytosis, -->  []
#
# Systemic -->  []
#
# -------------------------20-th new MDA--------------------------------------------
# miRNA = hsa-mir-151a  ||  disease_of_miRNA = Lung Diseases
# Lung -->  [['hsa-mir-151a' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-151a' nan 'Adenocarcinoma, Lung' nan]
#  ['hsa-mir-151a' nan 'Carcinoma, Non-Small-Cell Lung' nan]]
#
# Diseases -->  [['hsa-mir-151a' nan 'Cardiovascular Diseases [unspecific]' nan]]
#
# -------------------------21-th new MDA--------------------------------------------
# miRNA = hsa-mir-661  ||  disease_of_miRNA = Leukemia, Promyelocytic, Acute
# Leukemia, -->  []
#
# Promyelocytic, -->  []
#
# Acute -->  []
#
# -------------------------22-th new MDA--------------------------------------------
# miRNA = hsa-mir-2861  ||  disease_of_miRNA = Leukemia, B-Cell
# Leukemia, -->  []
#
# B-Cell -->  []
#
# -------------------------23-th new MDA--------------------------------------------
# miRNA = hsa-mir-641  ||  disease_of_miRNA = Leiomyosarcoma
# Leiomyosarcoma -->  []
#
# -------------------------24-th new MDA--------------------------------------------
# miRNA = hsa-mir-655  ||  disease_of_miRNA = Kidney Neoplasms
# Kidney -->  []
#
# Neoplasms -->  [['hsa-mir-655' nan 'Pituitary Neoplasms' nan]]
#
# -------------------------25-th new MDA--------------------------------------------
# miRNA = hsa-mir-614  ||  disease_of_miRNA = Kidney Failure, Acute
# Kidney -->  []
#
# Failure, -->  []
#
# Acute -->  []
#
# -------------------------26-th new MDA--------------------------------------------
#  61%|██████    | 31/51 [00:00<00:00, 34.83it/s]
# miRNA = hsa-mir-516a  ||  disease_of_miRNA = Ischemic Preconditioning
# Ischemic -->  []
#
# Preconditioning -->  []
#
# -------------------------27-th new MDA--------------------------------------------
# miRNA = hsa-mir-29a  ||  disease_of_miRNA = Huntington Disease
# Huntington -->  []
#
# Disease -->  [['hsa-mir-29a' nan 'Parkinson Disease' nan]
#  ['hsa-mir-29a' nan 'Alzheimer Disease' nan]
#  ['hsa-mir-29a' nan 'Machado-Joseph Disease' nan]
#  ['hsa-mir-29a' nan 'Liver Diseases [unspecific]' nan]
#  ['hsa-mir-29a' nan 'Crohn Disease' nan]
#  ['hsa-mir-29a' nan 'Kidney Diseases [unspecific]' nan]
#  ['hsa-mir-29a' nan 'Vascular Disease [unspecific]' nan]
#  ['hsa-mir-29a' nan 'Heart Valve Disease' nan]
#  ['hsa-mir-29a' nan 'Mitochondrial Metabolism Disease' nan]
#  ['hsa-mir-29a' nan 'Autoimmune Diseases [unspecific]' nan]
#  ['hsa-mir-29a' nan 'Kidney Diseases' nan]
#  ['hsa-mir-29a' nan 'Liver Diseases' nan]]
#
# -------------------------28-th new MDA--------------------------------------------
# miRNA = hsa-mir-190a  ||  disease_of_miRNA = Hepatitis C
# Hepatitis -->  []
#
# C -->  [['hsa-mir-190a' nan 'Carcinoma, Breast, Triple Negative' nan]
#  ['hsa-mir-190a' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-190a' nan 'Colorectal Carcinoma' nan]
#  ['hsa-mir-190a' nan 'Colorectal Neoplasms' nan]]
#
# -------------------------29-th new MDA--------------------------------------------
# miRNA = hsa-mir-1245a  ||  disease_of_miRNA = Hepatitis
# Hepatitis -->  []
#
# -------------------------30-th new MDA--------------------------------------------
# miRNA = hsa-mir-324  ||  disease_of_miRNA = Hemangiosarcoma
# Hemangiosarcoma -->  []
#
# -------------------------31-th new MDA--------------------------------------------
# miRNA = hsa-mir-532  ||  disease_of_miRNA = Hand, Foot and Mouth Disease
# Hand, -->  []
#
# Foot -->  []
#
# and -->  []
#
# Mouth -->  []
#
# Disease -->  [['hsa-mir-532' nan 'Alzheimer Disease' nan]
#  ['hsa-mir-532' nan 'Crohn Disease' nan]]
#
# -------------------------32-th new MDA--------------------------------------------
# miRNA = hsa-mir-622  ||  disease_of_miRNA = Graves Disease
# Graves -->  []
#
# Disease -->  []
#
# -------------------------33-th new MDA--------------------------------------------
# miRNA = hsa-mir-758  ||  disease_of_miRNA = Graft vs Host Disease
# Graft -->  []
#
# vs -->  []
#
# Host -->  []
#
# Disease -->  [['hsa-mir-758' nan 'Cardiovascular Diseases [unspecific]' nan]]
#
# -------------------------34-th new MDA--------------------------------------------
# miRNA = hsa-mir-320a  ||  disease_of_miRNA = Glomerulonephritis, IGA
# Glomerulonephritis, -->  []
#
# IGA -->  []
#
# -------------------------35-th new MDA--------------------------------------------
# miRNA = hsa-mir-941  ||  disease_of_miRNA = Fibrosis
# 100%|██████████| 51/51 [00:00<00:00, 52.70it/s]
# Fibrosis -->  []
#
# -------------------------36-th new MDA--------------------------------------------
# miRNA = hsa-mir-423  ||  disease_of_miRNA = Endometriosis
# Endometriosis -->  []
#
# -------------------------37-th new MDA--------------------------------------------
# miRNA = hsa-mir-15b  ||  disease_of_miRNA = Diabetic Nephropathies
# Diabetic -->  [['hsa-mir-15b' nan 'Diabetic Nephropathy' nan]]
#
# Nephropathies -->  []
#
# -------------------------38-th new MDA--------------------------------------------
# miRNA = hsa-mir-378f  ||  disease_of_miRNA = Diabetes Complications
# Diabetes -->  []
#
# Complications -->  []
#
# -------------------------39-th new MDA--------------------------------------------
# miRNA = hsa-mir-198  ||  disease_of_miRNA = Cystic Fibrosis
# Cystic -->  []
#
# Fibrosis -->  []
#
# -------------------------40-th new MDA--------------------------------------------
# miRNA = hsa-mir-1184  ||  disease_of_miRNA = Colorectal Neoplasms, Hereditary Nonpolyposis
# Colorectal -->  []
#
# Neoplasms, -->  []
#
# Hereditary -->  []
#
# Nonpolyposis -->  []
#
# -------------------------41-th new MDA--------------------------------------------
# miRNA = hsa-mir-494  ||  disease_of_miRNA = Colitis, Ulcerative
# Colitis, -->  []
#
# Ulcerative -->  []
#
# -------------------------42-th new MDA--------------------------------------------
# miRNA = hsa-mir-424  ||  disease_of_miRNA = Chondrodysplasia Punctata
# Chondrodysplasia -->  []
#
# Punctata -->  []
#
# -------------------------43-th new MDA--------------------------------------------
# miRNA = hsa-mir-655  ||  disease_of_miRNA = Carcinoma, Squamous Cell
# Carcinoma, -->  [['hsa-mir-655' nan 'Carcinoma, Renal Cell' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-655' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Esophageal' nan]]
#
# Squamous -->  [['hsa-mir-655' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Esophageal' nan]]
#
# Cell -->  [['hsa-mir-655' nan 'Carcinoma, Renal Cell' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Esophageal' nan]]
#
# -------------------------44-th new MDA--------------------------------------------
# miRNA = hsa-mir-365b  ||  disease_of_miRNA = Carcinoma, Ductal, Breast
# Carcinoma, -->  [['hsa-mir-365b' nan 'Carcinoma, Renal Cell' nan]
#  ['hsa-mir-365b' nan 'Carcinoma, Hepatocellular' nan]]
#
# Ductal, -->  []
#
# Breast -->  [['hsa-mir-365b' nan 'Breast Neoplasms' nan]]
#
# -------------------------45-th new MDA--------------------------------------------
# miRNA = hsa-mir-154  ||  disease_of_miRNA = Burns
# Burns -->  []
#
# -------------------------46-th new MDA--------------------------------------------
# miRNA = hsa-mir-30d  ||  disease_of_miRNA = Atrophy
# Atrophy -->  []
#
# -------------------------47-th new MDA--------------------------------------------
# miRNA = hsa-mir-30e  ||  disease_of_miRNA = Aortic Aneurysm, Abdominal
# Aortic -->  [['hsa-mir-30e' nan 'Aortic Aneurysm, Thoracic' nan]]
#
# Aneurysm, -->  [['hsa-mir-30e' nan 'Aortic Aneurysm, Thoracic' nan]]
#
# Abdominal -->  []
#
# -------------------------48-th new MDA--------------------------------------------
# miRNA = hsa-mir-410  ||  disease_of_miRNA = Alzheimer Disease
# Alzheimer -->  []
#
# Disease -->  [['hsa-mir-410' nan 'Pelvic Inflammatory Disease' nan]]
#
# -------------------------49-th new MDA--------------------------------------------
# miRNA = hsa-mir-630  ||  disease_of_miRNA = Alopecia
# Alopecia -->  []
#
# -------------------------50-th new MDA--------------------------------------------
# miRNA = hsa-mir-451b  ||  disease_of_miRNA = Acute Lung Injury
# Acute -->  []
#
# Lung -->  [['hsa-mir-451b' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-451b' nan 'Carcinoma, Non-Small-Cell Lung' nan]]
#
# Injury -->  []

# %%
results_Td, new_MDA_Td, new_MDA_simplied_Td, database_data_miRNA_in_results_Td = run(task = 'Td', database_data = database_data)
# Out:
# /home/chujunyi/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/chujunyi/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   4%|▍         | 3/68 [00:00<00:02, 27.30it/s]
# -------------------------0-th new MDA--------------------------------------------
# miRNA = hsa-mir-324  ||  disease_of_miRNA = Vascular Calcification
# Vascular -->  []
#
# Calcification -->  []
#
# -------------------------1-th new MDA--------------------------------------------
# miRNA = hsa-mir-582  ||  disease_of_miRNA = Thyroid Neoplasms
# Thyroid -->  []
#
# Neoplasms -->  [['hsa-mir-582' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-582' nan 'Prostate Neoplasms' nan]]
#
# -------------------------2-th new MDA--------------------------------------------
# miRNA = hsa-mir-342  ||  disease_of_miRNA = Stroke
# Stroke -->  []
#
# -------------------------3-th new MDA--------------------------------------------
# miRNA = hsa-mir-640  ||  disease_of_miRNA = Skin Neoplasms
# Skin -->  []
#
# Neoplasms -->  [['hsa-mir-640' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-640' nan 'Stomach Neoplasms' nan]]
#
# -------------------------4-th new MDA--------------------------------------------
# miRNA = hsa-mir-98  ||  disease_of_miRNA = Scleroderma, Systemic
# Scleroderma, -->  []
#
# Systemic -->  [['hsa-mir-98' nan 'Systemic Lupus Erythematosus' nan]]
#
# -------------------------5-th new MDA--------------------------------------------
# miRNA = hsa-mir-1256  ||  disease_of_miRNA = Scleroderma, Localized
# Scleroderma, -->  []
#
# Localized -->  []
#
# -------------------------6-th new MDA--------------------------------------------
# miRNA = hsa-mir-494  ||  disease_of_miRNA = Scleroderma, Localized
# Scleroderma, -->  []
#
# Localized -->  []
#
# -------------------------7-th new MDA--------------------------------------------
# miRNA = hsa-mir-15a  ||  disease_of_miRNA = Salivary Gland Neoplasms
#  19%|█▉        | 13/68 [00:00<00:01, 31.11it/s]
# Salivary -->  [['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]]
#
# Gland -->  [['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]]
#
# Neoplasms -->  [['hsa-mir-15a' nan 'Pituitary Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Prostate Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Kidney Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Breast Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Neoplasms [unspecific]' nan]
#  ['hsa-mir-15a' nan 'Hematologic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Colon Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Laryngeal Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Head And Neck Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Myeloproliferative Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Pancreatic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Salivary Gland Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Bladder Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Esophageal Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Prostatic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Head and Neck Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Colonic Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Urinary Bladder Neoplasms' nan]
#  ['hsa-mir-15a' nan 'Neoplasms' nan]]
#
# -------------------------8-th new MDA--------------------------------------------
# miRNA = hsa-mir-374a  ||  disease_of_miRNA = Rhinitis, Allergic, Perennial
# Rhinitis, -->  []
#
# Allergic, -->  []
#
# Perennial -->  []
#
# -------------------------9-th new MDA--------------------------------------------
# miRNA = hsa-mir-589  ||  disease_of_miRNA = Radiation Injuries
# Radiation -->  []
#
# Injuries -->  []
#
# -------------------------10-th new MDA--------------------------------------------
# miRNA = hsa-mir-526a  ||  disease_of_miRNA = Precursor B-Cell Lymphoblastic Leukemia-Lymphoma
# Precursor -->  []
#
# B-Cell -->  []
#
# Lymphoblastic -->  []
#
# Leukemia-Lymphoma -->  []
#
# -------------------------11-th new MDA--------------------------------------------
# miRNA = hsa-mir-641  ||  disease_of_miRNA = Papilary thyroid carcinoma
# Papilary -->  []
#
# thyroid -->  []
#
# carcinoma -->  []
#
# -------------------------12-th new MDA--------------------------------------------
# miRNA = hsa-mir-561  ||  disease_of_miRNA = Osteoporosis
# Osteoporosis -->  []
#
# -------------------------13-th new MDA--------------------------------------------
# miRNA = hsa-mir-922  ||  disease_of_miRNA = Nevus, Pigmented
# Nevus, -->  []
#  29%|██▉       | 20/68 [00:00<00:01, 31.47it/s]
# Pigmented -->  []
#
# -------------------------14-th new MDA--------------------------------------------
# miRNA = hsa-mir-4257  ||  disease_of_miRNA = Nervous System Diseases
# Nervous -->  []
#
# System -->  []
#
# Diseases -->  []
#
# -------------------------15-th new MDA--------------------------------------------
# miRNA = hsa-mir-449b  ||  disease_of_miRNA = Myocytes, Cardiac
# Myocytes, -->  []
#
# Cardiac -->  []
#
# -------------------------16-th new MDA--------------------------------------------
# miRNA = hsa-mir-181d  ||  disease_of_miRNA = Musculoskeletal Abnormalities
# Musculoskeletal -->  []
#
# Abnormalities -->  []
#
# -------------------------17-th new MDA--------------------------------------------
# miRNA = hsa-mir-938  ||  disease_of_miRNA = Muscular Dystrophy, Facioscapulohumeral
# Muscular -->  []
#
# Dystrophy, -->  []
#
# Facioscapulohumeral -->  []
#
# -------------------------18-th new MDA--------------------------------------------
# miRNA = hsa-mir-449b  ||  disease_of_miRNA = Mouth Neoplasms
# Mouth -->  []
#
# Neoplasms -->  [['hsa-mir-449b' nan 'Prostate Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Neoplasms [unspecific]' nan]
#  ['hsa-mir-449b' nan 'Liver Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Salivary Gland Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Ovarian Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Bladder Neoplasms' nan]
#  ['hsa-mir-449b' nan 'Stomach Neoplasms' nan]]
#
# -------------------------19-th new MDA--------------------------------------------
# miRNA = hsa-mir-545  ||  disease_of_miRNA = Mouth Neoplasms
# Mouth -->  [['hsa-mir-545' nan 'Hand, Foot And Mouth Disease' nan]
#  ['hsa-mir-545' nan 'Hand, Foot and Mouth Disease' nan]]
#
# Neoplasms -->  [['hsa-mir-545' nan 'Neoplasms [unspecific]' nan]
#  ['hsa-mir-545' nan 'Ovarian Neoplasms' nan]
#  ['hsa-mir-545' nan 'Lung Neoplasms' nan]
#  ['hsa-mir-545' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-545' nan 'Colon Neoplasms' nan]]
#
# -------------------------20-th new MDA--------------------------------------------
#  34%|███▍      | 23/68 [00:00<00:01, 26.29it/s]
# miRNA = hsa-mir-769  ||  disease_of_miRNA = Mastocytosis, Systemic
# Mastocytosis, -->  []
#
# Systemic -->  []
#
# -------------------------21-th new MDA--------------------------------------------
# miRNA = hsa-mir-654  ||  disease_of_miRNA = Lymphoma, Large-Cell, Anaplastic
# Lymphoma, -->  []
#
# Large-Cell, -->  []
#
# Anaplastic -->  []
#
# -------------------------22-th new MDA--------------------------------------------
# miRNA = hsa-mir-1293  ||  disease_of_miRNA = Lymphoma
# Lymphoma -->  []
#
# -------------------------23-th new MDA--------------------------------------------
# miRNA = hsa-mir-151a  ||  disease_of_miRNA = Lung Diseases
# Lung -->  [['hsa-mir-151a' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-151a' nan 'Adenocarcinoma, Lung' nan]
#  ['hsa-mir-151a' nan 'Carcinoma, Non-Small-Cell Lung' nan]]
#
# Diseases -->  [['hsa-mir-151a' nan 'Cardiovascular Diseases [unspecific]' nan]]
#
# -------------------------24-th new MDA--------------------------------------------
# miRNA = hsa-mir-19a  ||  disease_of_miRNA = Liver Diseases, Alcoholic
# Liver -->  []
#
# Diseases, -->  [['hsa-mir-19a' nan 'Lung Diseases, Interstitial' nan]]
#
# Alcoholic -->  []
#
# -------------------------25-th new MDA--------------------------------------------
# miRNA = hsa-mir-661  ||  disease_of_miRNA = Leukemia, Promyelocytic, Acute
# Leukemia, -->  []
#
# Promyelocytic, -->  []
#
# Acute -->  []
#
# -------------------------26-th new MDA--------------------------------------------
# miRNA = hsa-mir-150  ||  disease_of_miRNA = Leukemia, Promyelocytic, Acute
# Leukemia, -->  [['hsa-mir-150' nan 'Leukemia, Lymphocytic, Chronic, B-Cell' nan]
#  ['hsa-mir-150' nan 'Leukemia, Myeloid, Chronic' nan]
#  ['hsa-mir-150' nan 'Leukemia, Myeloid, Acute' nan]
#  ['hsa-mir-150' nan 'Leukemia, Lymphoblastic, Acute' nan]
#  ['hsa-mir-150' nan 'Leukemia, Acute' nan]
#  ['hsa-mir-150' nan 'Leukemia, Myeloid' nan]]
#
# Promyelocytic, -->  []
#  49%|████▊     | 33/68 [00:00<00:01, 33.17it/s]
# Acute -->  [['hsa-mir-150' nan 'Leukemia, Myeloid, Acute' nan]
#  ['hsa-mir-150' nan 'Leukemia, Lymphoblastic, Acute' nan]
#  ['hsa-mir-150' nan 'Leukemia, Acute' nan]
#  ['hsa-mir-150' nan 'Acute Myocardial Infarction' nan]]
#
# -------------------------27-th new MDA--------------------------------------------
# miRNA = hsa-mir-641  ||  disease_of_miRNA = Leiomyosarcoma
# Leiomyosarcoma -->  []
#
# -------------------------28-th new MDA--------------------------------------------
# miRNA = hsa-mir-1280  ||  disease_of_miRNA = Leiomyosarcoma
# Leiomyosarcoma -->  []
#
# -------------------------29-th new MDA--------------------------------------------
# miRNA = hsa-mir-655  ||  disease_of_miRNA = Kidney Neoplasms
# Kidney -->  []
#
# Neoplasms -->  [['hsa-mir-655' nan 'Pituitary Neoplasms' nan]]
#
# -------------------------30-th new MDA--------------------------------------------
# miRNA = hsa-mir-520f  ||  disease_of_miRNA = Ischemia
# Ischemia -->  []
#
# -------------------------31-th new MDA--------------------------------------------
# miRNA = hsa-let-7g  ||  disease_of_miRNA = HEV
# HEV -->  []
#
# -------------------------32-th new MDA--------------------------------------------
# miRNA = hsa-mir-190a  ||  disease_of_miRNA = Hepatitis C
# Hepatitis -->  []
#
# C -->  [['hsa-mir-190a' nan 'Carcinoma, Breast, Triple Negative' nan]
#  ['hsa-mir-190a' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-190a' nan 'Colorectal Carcinoma' nan]
#  ['hsa-mir-190a' nan 'Colorectal Neoplasms' nan]]
#
# -------------------------33-th new MDA--------------------------------------------
# miRNA = hsa-mir-497  ||  disease_of_miRNA = Hepatitis C
# Hepatitis -->  []
#
# C -->  [['hsa-mir-497' nan 'Carcinoma, Cervical' nan]
#  ['hsa-mir-497' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-497' nan 'Invasive Bladder Transitional Cell Carcinoma' nan]
#  ['hsa-mir-497' nan 'Carcinoma, Ovarian' nan]
#  ['hsa-mir-497' nan 'Squamous Cell Carcinoma, Cerevial' nan]
#  ['hsa-mir-497' nan 'Colorectal Carcinoma' nan]
#  ['hsa-mir-497' nan 'Leukemia, Lymphocytic, Chronic, B-Cell' nan]
#  ['hsa-mir-497' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-497' nan 'Cerebral Ischemia' nan]
#  ['hsa-mir-497' nan 'Carcinoma, Renal Cell, Clear-Cell' nan]
#  ['hsa-mir-497' nan 'Urinary Bladder Cancer' nan]
#  ['hsa-mir-497' nan 'Carcinoma, Adrenocortical' nan]
#  ['hsa-mir-497' nan 'Cardiomyopathy, Hypertrophic' nan]
#  ['hsa-mir-497' nan 'Squamous Cell Carcinoma' nan]
#  ['hsa-mir-497' nan 'Carcinoma, Squamous Cell' nan]
#  ['hsa-mir-497' nan 'Colorectal Neoplasms' nan]
#  ['hsa-mir-497' nan 'Uterine Cervical Neoplasms' nan]
#  ['hsa-mir-497' nan 'Carcinoma, Non-Small-Cell Lung' nan]]
#
# -------------------------34-th new MDA--------------------------------------------
# miRNA = hsa-mir-1245a  ||  disease_of_miRNA = Hepatitis
# Hepatitis -->  []
#
# -------------------------35-th new MDA--------------------------------------------
# miRNA = hsa-mir-324  ||  disease_of_miRNA = Hemangiosarcoma
# Hemangiosarcoma
#  66%|██████▌   | 45/68 [00:01<00:00, 38.52it/s]
#  -->  []
#
# -------------------------36-th new MDA--------------------------------------------
# miRNA = hsa-mir-448  ||  disease_of_miRNA = Helplessness, Learned
# Helplessness, -->  []
#
# Learned -->  []
#
# -------------------------37-th new MDA--------------------------------------------
# miRNA = hsa-mir-147a  ||  disease_of_miRNA = Hearing Loss
# Hearing -->  []
#
# Loss -->  []
#
# -------------------------38-th new MDA--------------------------------------------
# miRNA = hsa-mir-611  ||  disease_of_miRNA = HCMV Infection
# HCMV -->  []
#
# Infection -->  []
#
# -------------------------39-th new MDA--------------------------------------------
# miRNA = hsa-mir-758  ||  disease_of_miRNA = Graft vs Host Disease
# Graft -->  []
#
# vs -->  []
#
# Host -->  []
#
# Disease -->  [['hsa-mir-758' nan 'Cardiovascular Diseases [unspecific]' nan]]
#
# -------------------------40-th new MDA--------------------------------------------
# miRNA = hsa-mir-200c  ||  disease_of_miRNA = Gout
# Gout -->  []
#
# -------------------------41-th new MDA--------------------------------------------
# miRNA = hsa-mir-1285  ||  disease_of_miRNA = Giant Cell Tumors
# Giant -->  []
#
# Cell -->  [['hsa-mir-1285' nan 'Carcinoma, Lung, Non-Small-Cell' nan]]
#
# Tumors -->  []
#
# -------------------------42-th new MDA--------------------------------------------
# miRNA = hsa-mir-346  ||  disease_of_miRNA = Gastric Neoplasms
# Gastric -->  []
#
# Neoplasms -->  [['hsa-mir-346' nan 'Lung Neoplasms' nan]]
#
# -------------------------43-th new MDA--------------------------------------------
# miRNA = hsa-mir-628  ||  disease_of_miRNA = Focal Epithelial Hyperplasia
# Focal -->  []
#
# Epithelial -->  []
#
# Hyperplasia -->  []
#
# -------------------------44-th new MDA--------------------------------------------
# miRNA = hsa-mir-30a  ||  disease_of_miRNA = Focal Epithelial Hyperplasia
# Focal -->  [['hsa-mir-30a' nan 'Focal Segmental Glomerulosclerosis' nan]]
#
# Epithelial -->  []
#
# Hyperplasia -->  []
#
# -------------------------45-th new MDA--------------------------------------------
# miRNA = hsa-mir-181c  ||  disease_of_miRNA = Fatty Liver
# Fatty -->  []
#
# Liver -->  []
#
# -------------------------46-th new MDA--------------------------------------------
# miRNA = hsa-mir-423  ||  disease_of_miRNA = Endometriosis
#  74%|███████▎  | 50/68 [00:01<00:00, 35.78it/s]
# Endometriosis -->  []
#
# -------------------------47-th new MDA--------------------------------------------
# miRNA = hsa-mir-30c  ||  disease_of_miRNA = Encephalomyelitis, Autoimmune, Experimental
# Encephalomyelitis, -->  []
#
# Autoimmune, -->  []
#
# Experimental -->  []
#
# -------------------------48-th new MDA--------------------------------------------
# miRNA = hsa-mir-1293  ||  disease_of_miRNA = Digestive System Neoplasms
# Digestive -->  []
#
# System -->  []
#
# Neoplasms -->  []
#
# -------------------------49-th new MDA--------------------------------------------
# miRNA = hsa-mir-873  ||  disease_of_miRNA = Diabetic Retinopathy
# Diabetic -->  []
#
# Retinopathy -->  []
#
# -------------------------50-th new MDA--------------------------------------------
# miRNA = hsa-mir-15b  ||  disease_of_miRNA = Diabetic Nephropathies
# Diabetic -->  [['hsa-mir-15b' nan 'Diabetic Nephropathy' nan]]
#
# Nephropathies -->  []
#
# -------------------------51-th new MDA--------------------------------------------
# miRNA = hsa-mir-143  ||  disease_of_miRNA = Colitis
# Colitis -->  [['hsa-mir-143' nan 'Colitis, Ulcerative' nan]]
#
# -------------------------52-th new MDA--------------------------------------------
# miRNA = hsa-mir-100  ||  disease_of_miRNA = Cocaine-Related Disorders
# Cocaine-Related -->  []
#
# Disorders -->  [['hsa-mir-100' nan 'Muscular Disorders, Atrophic' nan]]
#
# -------------------------53-th new MDA--------------------------------------------
# miRNA = hsa-mir-425  ||  disease_of_miRNA = Child Development Disorders, Pervasive
# Child -->  []
#
# Development -->  []
#  87%|████████▋ | 59/68 [00:01<00:00, 35.18it/s]
# Disorders, -->  []
#
# Pervasive -->  []
#
# -------------------------54-th new MDA--------------------------------------------
# miRNA = hsa-mir-337  ||  disease_of_miRNA = Cervical Neoplasms
# Cervical -->  [['hsa-mir-337' nan 'Carcinoma, Cervical' nan]]
#
# Neoplasms -->  [['hsa-mir-337' nan 'Gastric Neoplasms' nan]
#  ['hsa-mir-337' nan 'Salivary Gland Neoplasms' nan]
#  ['hsa-mir-337' nan 'Colorectal Neoplasms' nan]]
#
# -------------------------55-th new MDA--------------------------------------------
# miRNA = hsa-mir-625  ||  disease_of_miRNA = Central Nervous System Diseases
# Central -->  []
#
# Nervous -->  []
#
# System -->  []
#
# Diseases -->  []
#
# -------------------------56-th new MDA--------------------------------------------
# miRNA = hsa-mir-655  ||  disease_of_miRNA = Carcinoma, Squamous Cell
# Carcinoma, -->  [['hsa-mir-655' nan 'Carcinoma, Renal Cell' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-655' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Esophageal' nan]]
#
# Squamous -->  [['hsa-mir-655' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Esophageal' nan]]
#
# Cell -->  [['hsa-mir-655' nan 'Carcinoma, Renal Cell' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-655' nan 'Squamous Cell Carcinoma, Esophageal' nan]]
#
# -------------------------57-th new MDA--------------------------------------------
# miRNA = hsa-mir-504  ||  disease_of_miRNA = Carcinoma, Neuroendocrine
# Carcinoma, -->  [['hsa-mir-504' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-504' nan
#   'Squamous Cell Carcinoma, Laryngeal or Hypopharyngeal' nan]
#  ['hsa-mir-504' nan 'Carcinoma, Hepatocellular' nan]
#  ['hsa-mir-504' nan 'Carcinoma, Nasopharyngeal' nan]
#  ['hsa-mir-504' nan 'Carcinoma, Squamous Cell' nan]]
#
# Neuroendocrine -->  []
#
# -------------------------58-th new MDA--------------------------------------------
# miRNA = hsa-mir-154  ||  disease_of_miRNA = Burns
# Burns -->  []
#
# -------------------------59-th new MDA--------------------------------------------
# miRNA = hsa-mir-95  ||  disease_of_miRNA = Brain Ischemia
# Brain -->  []
#
# Ischemia -->  []
#
# -------------------------60-th new MDA--------------------------------------------
# miRNA = hsa-mir-198  ||  disease_of_miRNA = Brain Injuries
# Brain -->  []
#
# Injuries -->  []
#
# -------------------------61-th new MDA--------------------------------------------
# miRNA = hsa-mir-1285  ||  disease_of_miRNA = Asthma
# Asthma -->  []
#
# -------------------------62-th new MDA--------------------------------------------
# miRNA = hsa-mir-137  ||  disease_of_miRNA = Anemia, Sickle Cell
# Anemia, -->  []
#
# Sickle -->  []
#
# Cell -->  [['hsa-mir-137' nan 'Squamous Cell Carcinoma, Oral' nan]
#  ['hsa-mir-137' nan 'Squamous Cell Carcinoma, Head and Neck' nan]
#  ['hsa-mir-137' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-137' nan 'Squamous Cell Carcinoma, Tongue' nan]
#  ['hsa-mir-137' nan 'Carcinoma, Renal Cell' nan]
#  ['hsa-mir-137' nan 'Carcinoma, Lung, Small-Cell' nan]
#  ['hsa-mir-137' nan 'Carcinoma, Squamous Cell' nan]]
#
# -------------------------63-th new MDA--------------------------------------------
# miRNA = hsa-mir-410  ||  disease_of_miRNA = Alzheimer Disease
# Alzheimer -->  []
#
# Disease -->  [['hsa-mir-410' nan 'Pelvic Inflammatory Disease' nan]]
#
# -------------------------64-th new MDA--------------------------------------------
# miRNA = hsa-mir-566  ||  disease_of_miRNA = Adrenocortical Adenoma
# 100%|██████████| 68/68 [00:01<00:00, 36.35it/s]
# Adrenocortical -->  []
#
# Adenoma -->  []
#
# -------------------------65-th new MDA--------------------------------------------
# miRNA = hsa-mir-181d  ||  disease_of_miRNA = Adenocarcinoma
# Adenocarcinoma -->  []
#
# -------------------------66-th new MDA--------------------------------------------
# miRNA = hsa-mir-451b  ||  disease_of_miRNA = Acute Lung Injury
# Acute -->  []
#
# Lung -->  [['hsa-mir-451b' nan 'Carcinoma, Lung, Non-Small-Cell' nan]
#  ['hsa-mir-451b' nan 'Carcinoma, Non-Small-Cell Lung' nan]]
#
# Injury -->  []
#
# -------------------------67-th new MDA--------------------------------------------
# miRNA = hsa-mir-1273a  ||  disease_of_miRNA = Abortion, Habitual
# Abortion, -->  []
#
# Habitual -->  []

# %% [markdown]
# # 整理

# %%
results_Td
# Out:
#       miRNA_x  disease_x  y_true  y_pred    y_prob       miRNA_y  \
# 8048      116        383     1.0     1.0  0.999104   hsa-mir-483
# 8049        9        383     1.0     1.0  0.999097   hsa-mir-143
# 8037      148        383     1.0     1.0  0.999097     hsa-mir-9
# 8036       14        383     1.0     1.0  0.999079    hsa-mir-21
# 8034       10        383     1.0     1.0  0.998415   hsa-mir-145
# ...       ...        ...     ...     ...       ...           ...
# 8554      482          1     0.0     0.0  0.001152   hsa-mir-570
# 8543       24          1     0.0     0.0  0.001151   hsa-mir-126
# 8551      164          1     0.0     0.0  0.001149    hsa-let-7i
# 8553      454          1     0.0     0.0  0.001148   hsa-mir-767
# 8552       63          1     0.0     0.0  0.001148  hsa-mir-1246
#
#                     disease_y
# 8048  ['Wounds and Injuries']
# 8049  ['Wounds and Injuries']
# 8037  ['Wounds and Injuries']
# 8036  ['Wounds and Injuries']
# 8034  ['Wounds and Injuries']
# ...                       ...
# 8554   ['Abortion, Habitual']
# 8543   ['Abortion, Habitual']
# 8551   ['Abortion, Habitual']
# 8553   ['Abortion, Habitual']
# 8552   ['Abortion, Habitual']
#
# [10860 rows x 7 columns]

# %%
results_Td[results_Td['y_true'] == 1][results_Td['y_pred'] == 1]
# Out:
# /home/chujunyi/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       miRNA_x  disease_x  y_true  y_pred    y_prob       miRNA_y  \
# 8048      116        383     1.0     1.0  0.999104   hsa-mir-483
# 8049        9        383     1.0     1.0  0.999097   hsa-mir-143
# 8037      148        383     1.0     1.0  0.999097     hsa-mir-9
# 8036       14        383     1.0     1.0  0.999079    hsa-mir-21
# 8034       10        383     1.0     1.0  0.998415   hsa-mir-145
# ...       ...        ...     ...     ...       ...           ...
# 3543        4          2     1.0     1.0  0.998640   hsa-mir-198
# 3546        6          2     1.0     1.0  0.998612   hsa-mir-29b
# 8537        2          1     1.0     1.0  0.999107  hsa-mir-196a
# 8541        3          1     1.0     1.0  0.999105  hsa-mir-499a
# 8549        1          1     1.0     1.0  0.999089  hsa-mir-125a
#
#                                    disease_y
# 8048                 ['Wounds and Injuries']
# 8049                 ['Wounds and Injuries']
# 8037                 ['Wounds and Injuries']
# 8036                 ['Wounds and Injuries']
# 8034                 ['Wounds and Injuries']
# ...                                      ...
# 3543  ['Acquired Immunodeficiency Syndrome']
# 3546  ['Acquired Immunodeficiency Syndrome']
# 8537                  ['Abortion, Habitual']
# 8541                  ['Abortion, Habitual']
# 8549                  ['Abortion, Habitual']
#
# [5297 rows x 7 columns]

# %% [markdown]
# # Nouse

# %%
new_MDA_Tp_balanced_simplied_2 = pd.DataFrame(new_MDA_Tp_balanced_simplied.groupby('miRNA_y')['disease_newMDA'].apply(list))
database_data_miRNA_in_Tp_balanced_simplied = pd.DataFrame(database_data_miRNA_in_Tp_balanced.groupby('miRNA')['disease'].apply(list))
new_MDA_Tp_balanced__database_data__merged = pd.merge(new_MDA_Tp_balanced_simplied_2, database_data_miRNA_in_Tp_balanced_simplied, left_index = True, right_index = True)
new_MDA_Tp_balanced__database_data__merged
# Out:
#                             disease_newMDA  \
# miRNA_y
# hsa-mir-100    [Cocaine-Related Disorders]
# hsa-mir-10b                       [Sepsis]
# hsa-mir-1181           [Oligodendroglioma]
# hsa-mir-1245a                  [Hepatitis]
# hsa-mir-1273a         [Abortion, Habitual]
# ...                                    ...
# hsa-mir-758        [Graft vs Host Disease]
# hsa-mir-769       [Mastocytosis, Systemic]
# hsa-mir-873         [Diabetic Retinopathy]
# hsa-mir-922             [Nevus, Pigmented]
# hsa-mir-942                     [Ischemia]
#
#                                                          disease
# miRNA_y
# hsa-mir-100    [Carcinoma, Adrenocortical, Muscle Atrophy, At...
# hsa-mir-10b    [Breast Neoplasms, Leukemia, Huntington Diseas...
# hsa-mir-1181   [Hepatitis C Virus Infection, Pancreatic Neopl...
# hsa-mir-1245a                                 [Breast Neoplasms]
# hsa-mir-1273a    [Adenovirus Infection, Adenoviridae Infections]
# ...                                                          ...
# hsa-mir-758    [HELLP Syndrome, Systemic Lupus Erythematosus,...
# hsa-mir-769    [Lupus Vulgaris, Squamous Cell Carcinoma, Oral...
# hsa-mir-873    [Ectopic Pregnancy, Liver Cirrhosis, Johne Dis...
# hsa-mir-922    [Breast Neoplasms, Alzheimer Disease, Carcinom...
# hsa-mir-942    [Nephrotic Syndrome, Carcinoma, Breast, Kaposi...
#
# [75 rows x 2 columns]

# %%
new_MDA_table = new_MDA_Tp_balanced__database_data__merged['disease_newMDA']
database_data_table = new_MDA_Tp_balanced__database_data__merged['disease']
new_MDA_table
# Out:
# miRNA_y
# hsa-mir-100      [Cocaine-Related Disorders]
# hsa-mir-10b                         [Sepsis]
# hsa-mir-1181             [Oligodendroglioma]
# hsa-mir-1245a                    [Hepatitis]
# hsa-mir-1273a           [Abortion, Habitual]
#                             ...
# hsa-mir-758          [Graft vs Host Disease]
# hsa-mir-769         [Mastocytosis, Systemic]
# hsa-mir-873           [Diabetic Retinopathy]
# hsa-mir-922               [Nevus, Pigmented]
# hsa-mir-942                       [Ischemia]
# Name: disease_newMDA, Length: 75, dtype: object

# %%
temp.loc[temp[0].str.contains(s)].values
# Out:
# array([['Muscular Disorders, Atrophic']], dtype=object)

# %%
newMDA_disease = new_MDA_table[0][0].split(' ')
temp = pd.DataFrame(database_data_table[0])
for s in newMDA_disease:
    print(s)
    print(temp.loc[temp[0].str.contains(s)])
# Out:
# Cocaine-Related
# Empty DataFrame
# Columns: [0]
# Index: []
# Disorders
#                                0
# 66  Muscular Disorders, Atrophic

# %%
database_disease = ','.join(database_data_table[0])
database_disease
# Out:
# 'Carcinoma, Adrenocortical,Muscle Atrophy,Atherosclerosis,Adrenal Cortex Neoplasms,Breast Neoplasms,Acute Coronary Syndrome,Coronary Atherosclerosis,Diabetes Mellitus, Type 1,Esophageal Neoplasms,Recurrent Spontaneous Abortion,Leukemia-Lymphoma, Precursor T-Cell Lymphoblastic,Carcinoma, Lung, Non-Small-Cell,Squamous Cell Carcinoma, Esophageal,Urinary Bladder Cancer,Carcinoma, Hepatocellular,Bladder Neoplasms,Gastric Neoplasms,Leukemia, Myeloid, Acute,Prostate Neoplasms,Carcinoma, Renal Cell,Ovarian Neoplasms,Osteosarcoma,Heart Failure,Leukemia, Lymphoblastic, Acute,Vulvar Squamous Cell Carcinoma,Neoplasms [unspecific],Pancreatic Neoplasms,Cardiovascular Diseases [unspecific],Colorectal Carcinoma,Inflammation,Carcinoma, Rectal,Peritoneal Dialysis Failure,Vascular Injuries,Carcinoma, Ovarian,Infection [unspecific],Carcinoma, Bladder,Carcinoma, Gastric,Squamous Cell Carcinoma, Head and Neck,Melanoma,Carcinoma, Colon,Pneumonia,Nasopharyngeal Neoplasms,Endometrial Neoplasms,Lung Neoplasms,Kaposi Sarcoma,Glioblastoma,Chondrosarcoma,Alzheimer Disease,IgA Nephropathy,Carcinoma, Breast,Thyroid Neoplasms,Heart Diseases [unspecific],Carotid Atherosclerosis,Adenocarcinoma, Gastric,Adenocarcinoma, Pancreatic Ductal,Multiple Sclerosis,Carcinoma, Cervical,Head And Neck Neoplasms,Carcinoma, Lung, Small-Cell,Chronic Obstructive Pulmonary Disease,Squamous Cell Carcinoma, Oral,Psoriasis,Periodontitis,Carcinoma, Urothelial,Endometriosis,Muscular Dystrophy,Muscular Disorders, Atrophic,Adrenocortical Carcinoma,Stomach Neoplasms,Prostatic Neoplasms,Precursor Cell Lymphoblastic Leukemia-Lymphoma,Head and Neck Neoplasms,Carcinoma, Squamous Cell,Uterine Cervical Neoplasms,Muscular Dystrophies,Carcinoma, Small Cell,Urinary Bladder Neoplasms,Pulmonary Disease, Chronic Obstructive,Carcinoma, Non-Small-Cell Lung'

# %%
for i in range(len(new_MDA_table[0])):
    for j in range(len(database_data_table[0])):
        a = new_MDA_table[0][i]
        b = database_data_table[0][j]
        temp = re.findall(a, b)
        print(a, '\t', b)
# Out:
# Cocaine-Related Disorders 	 Carcinoma, Adrenocortical
# Cocaine-Related Disorders 	 Muscle Atrophy
# Cocaine-Related Disorders 	 Atherosclerosis
# Cocaine-Related Disorders 	 Adrenal Cortex Neoplasms
# Cocaine-Related Disorders 	 Breast Neoplasms
# Cocaine-Related Disorders 	 Acute Coronary Syndrome
# Cocaine-Related Disorders 	 Coronary Atherosclerosis
# Cocaine-Related Disorders 	 Diabetes Mellitus, Type 1
# Cocaine-Related Disorders 	 Esophageal Neoplasms
# Cocaine-Related Disorders 	 Recurrent Spontaneous Abortion
# Cocaine-Related Disorders 	 Leukemia-Lymphoma, Precursor T-Cell Lymphoblastic
# Cocaine-Related Disorders 	 Carcinoma, Lung, Non-Small-Cell
# Cocaine-Related Disorders 	 Squamous Cell Carcinoma, Esophageal
# Cocaine-Related Disorders 	 Urinary Bladder Cancer
# Cocaine-Related Disorders 	 Carcinoma, Hepatocellular
# Cocaine-Related Disorders 	 Bladder Neoplasms
# Cocaine-Related Disorders 	 Gastric Neoplasms
# Cocaine-Related Disorders 	 Leukemia, Myeloid, Acute
# Cocaine-Related Disorders 	 Prostate Neoplasms
# Cocaine-Related Disorders 	 Carcinoma, Renal Cell
# Cocaine-Related Disorders 	 Ovarian Neoplasms
# Cocaine-Related Disorders 	 Osteosarcoma
# Cocaine-Related Disorders 	 Heart Failure
# Cocaine-Related Disorders 	 Leukemia, Lymphoblastic, Acute
# Cocaine-Related Disorders 	 Vulvar Squamous Cell Carcinoma
# Cocaine-Related Disorders 	 Neoplasms [unspecific]
# Cocaine-Related Disorders 	 Pancreatic Neoplasms
# Cocaine-Related Disorders 	 Cardiovascular Diseases [unspecific]
# Cocaine-Related Disorders 	 Colorectal Carcinoma
# Cocaine-Related Disorders 	 Inflammation
# Cocaine-Related Disorders 	 Carcinoma, Rectal
# Cocaine-Related Disorders 	 Peritoneal Dialysis Failure
# Cocaine-Related Disorders 	 Vascular Injuries
# Cocaine-Related Disorders 	 Carcinoma, Ovarian
# Cocaine-Related Disorders 	 Infection [unspecific]
# Cocaine-Related Disorders 	 Carcinoma, Bladder
# Cocaine-Related Disorders 	 Carcinoma, Gastric
# Cocaine-Related Disorders 	 Squamous Cell Carcinoma, Head and Neck
# Cocaine-Related Disorders 	 Melanoma
# Cocaine-Related Disorders 	 Carcinoma, Colon
# Cocaine-Related Disorders 	 Pneumonia
# Cocaine-Related Disorders 	 Nasopharyngeal Neoplasms
# Cocaine-Related Disorders 	 Endometrial Neoplasms
# Cocaine-Related Disorders 	 Lung Neoplasms
# Cocaine-Related Disorders 	 Kaposi Sarcoma
# Cocaine-Related Disorders 	 Glioblastoma
# Cocaine-Related Disorders 	 Chondrosarcoma
# Cocaine-Related Disorders 	 Alzheimer Disease
# Cocaine-Related Disorders 	 IgA Nephropathy
# Cocaine-Related Disorders 	 Carcinoma, Breast
# Cocaine-Related Disorders 	 Thyroid Neoplasms
# Cocaine-Related Disorders 	 Heart Diseases [unspecific]
# Cocaine-Related Disorders 	 Carotid Atherosclerosis
# Cocaine-Related Disorders 	 Adenocarcinoma, Gastric
# Cocaine-Related Disorders 	 Adenocarcinoma, Pancreatic Ductal
# Cocaine-Related Disorders 	 Multiple Sclerosis
# Cocaine-Related Disorders 	 Carcinoma, Cervical
# Cocaine-Related Disorders 	 Head And Neck Neoplasms
# Cocaine-Related Disorders 	 Carcinoma, Lung, Small-Cell
# Cocaine-Related Disorders 	 Chronic Obstructive Pulmonary Disease
# Cocaine-Related Disorders 	 Squamous Cell Carcinoma, Oral
# Cocaine-Related Disorders 	 Psoriasis
# Cocaine-Related Disorders 	 Periodontitis
# Cocaine-Related Disorders 	 Carcinoma, Urothelial
# Cocaine-Related Disorders 	 Endometriosis
# Cocaine-Related Disorders 	 Muscular Dystrophy
# Cocaine-Related Disorders 	 Muscular Disorders, Atrophic
# Cocaine-Related Disorders 	 Adrenocortical Carcinoma
# Cocaine-Related Disorders 	 Stomach Neoplasms
# Cocaine-Related Disorders 	 Prostatic Neoplasms
# Cocaine-Related Disorders 	 Precursor Cell Lymphoblastic Leukemia-Lymphoma
# Cocaine-Related Disorders 	 Head and Neck Neoplasms
# Cocaine-Related Disorders 	 Carcinoma, Squamous Cell
# Cocaine-Related Disorders 	 Uterine Cervical Neoplasms
# Cocaine-Related Disorders 	 Muscular Dystrophies
# Cocaine-Related Disorders 	 Carcinoma, Small Cell
# Cocaine-Related Disorders 	 Urinary Bladder Neoplasms
# Cocaine-Related Disorders 	 Pulmonary Disease, Chronic Obstructive
# Cocaine-Related Disorders 	 Carcinoma, Non-Small-Cell Lung
